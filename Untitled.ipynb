# %%
import psutil ; print(list(psutil.virtual_memory())[0:2])

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

import xgboost as xgb

import pickle

import gc
gc.collect()
print(list(psutil.virtual_memory())[0:2])
# Out:
# [8589934592, 1268486144]
# [8589934592, 1188524032]
# /Users/abhisheksubramanian/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
import GAN_171103
import importlib
importlib.reload(GAN_171103) # For reloading after making changes
from GAN_171103 import *
# Out:
# /Users/abhisheksubramanian/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
a = np.random.normal(size=1000)
b = np.random.normal(size=1000)
c =  np.random.normal(size = 1000)

# %%
df = pd.DataFrame({'a':a,'b':b,'c':c})

# %%
df.head()
# Out:
#           a         b         c
# 0 -0.084322 -0.571847 -1.470656
# 1 -0.544641 -0.770086  1.857543
# 2 -0.587859 -0.189082  1.676962
# 3  0.477796 -1.163288 -1.087880
# 4 -0.549447 -0.866057  0.589900

# %%
rand_dim = 3 # 32 # needs to be ~data_dim
base_n_count = 128 # 128

nb_steps = 50 + 1 # 50000 # Add one for logging of the last interval
batch_size = 128 # 64

k_d = 1  # number of critic network updates per adversarial training step
k_g = 1  # number of generator network updates per adversarial training step
critic_pre_train_steps = 100 # 100  # number of steps to pre-train the critic before starting adversarial training
log_interval = 100 # 100  # interval (in steps) at which to log loss summaries and save plots of image samples to disc
learning_rate = 5e-4 # 5e-5
data_dir = 'cache/'
generator_model_path, discriminator_model_path, loss_pickle_path = None, None, None

# show = False
show = True 
arguments = [rand_dim, nb_steps, batch_size, 
             k_d, k_g, critic_pre_train_steps, log_interval, learning_rate, base_n_count,
            data_dir, generator_model_path, discriminator_model_path, loss_pickle_path, show ]

# %%
data_cols = [ i for i in df.columns]
# df[ data_cols ] = train[ data_cols ] / 10 # scale to random noise size, one less thing to learn
train_no_label = df[ data_cols ]

# %%
adversarial_training_GAN(arguments, train_no_label, data_cols )
# Out:
# data_dim:  3
# data_cols:  ['a', 'b', 'c']
# WARNING:tensorflow:From /Users/abhisheksubramanian/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1299: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               512
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               131584
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 166,659
# Trainable params: 166,659
# Non-trainable params: 0
# _________________________________________________________________
# None
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 3)                 0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               2048
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 166,401
# Trainable params: 0
# Non-trainable params: 166,401
# _________________________________________________________________
# None
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3)                 0
# _________________________________________________________________
# generator (Model)            (None, 3)                 166659
# _________________________________________________________________
# discriminator (Model)        (None, 1)                 166401
# =================================================================
# Total params: 333,060
# Trainable params: 166,659
# Non-trainable params: 166,401
# _________________________________________________________________
# None
# Step: 0 of 51.
# Losses: G, D Gen, D Real, Xgb: 0.6841, 0.7046, 0.6578, 0.9878
# D Real - D Gen: -0.0469

# %%
adversarial_training_WGAN(arguments, train_no_label, data_cols=data_cols )
# Out:
# data_dim:  3
# data_cols:  ['a', 'b', 'c']
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 3)                 0
# _________________________________________________________________
# dense_25 (Dense)             (None, 128)               512
# _________________________________________________________________
# dense_26 (Dense)             (None, 256)               33024
# _________________________________________________________________
# dense_27 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_28 (Dense)             (None, 3)                 1539
# =================================================================
# Total params: 166,659
# Trainable params: 166,659
# Non-trainable params: 0
# _________________________________________________________________
# None
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         (None, 3)                 0
# _________________________________________________________________
# dense_29 (Dense)             (None, 512)               2048
# _________________________________________________________________
# dense_30 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_31 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_32 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 166,401
# Trainable params: 0
# Non-trainable params: 166,401
# _________________________________________________________________
# None
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 3)                 0
# _________________________________________________________________
# generator (Model)            multiple                  166659
# _________________________________________________________________
# discriminator (Model)        multiple                  166401
# =================================================================
# Total params: 333,060
# Trainable params: 166,659
# Non-trainable params: 166,401
# _________________________________________________________________
# None
# pre-training the critic...
# Step: 0 of 100 critic pre-training.
# Step: 20 of 100 critic pre-training.
# Step: 40 of 100 critic pre-training.
# Step: 60 of 100 critic pre-training.
# Step: 80 of 100 critic pre-training.
# Last batch of critic pre-training disc_loss: (-0.19816749, -0.090923116).
# Step: 0 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.1992, -0.2000, -0.0999, 0.9858
# D Real - D Gen: 0.1002
# Step: 100 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.1230, -0.1088, -0.2025, 0.9634
# D Real - D Gen: -0.0936
# Step: 200 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.0506, -0.0277, 0.0184, 0.9167
# D Real - D Gen: 0.0462
# Step: 300 of 5001.
# Losses: G, D Gen, D Real, Xgb: -0.0343, 0.0365, 0.0906, 0.9512
# D Real - D Gen: 0.0541
# Step: 400 of 5001.
# Losses: G, D Gen, D Real, Xgb: -0.0405, 0.0422, 0.0248, 0.8699
# D Real - D Gen: -0.0174
# Step: 500 of 5001.
# Losses: G, D Gen, D Real, Xgb: -0.0440, 0.0475, 0.1674, 0.9146
# D Real - D Gen: 0.1200
# Step: 600 of 5001.
# Losses: G, D Gen, D Real, Xgb: -0.1230, 0.1535, 0.1401, 0.8882
# D Real - D Gen: -0.0133
# Step: 700 of 5001.
# Losses: G, D Gen, D Real, Xgb: -0.0382, 0.0263, 0.0408, 0.8313
# D Real - D Gen: 0.0145
# Step: 800 of 5001.
# Losses: G, D Gen, D Real, Xgb: -0.0557, 0.1512, 0.0680, 0.9126
# D Real - D Gen: -0.0832
# Step: 900 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.1023, -0.0783, -0.0763, 0.7134
# D Real - D Gen: 0.0020
# Step: 1000 of 5001.
# Losses: G, D Gen, D Real, Xgb: -0.0505, 0.0405, 0.0964, 0.7541
# D Real - D Gen: 0.0560
# Step: 1100 of 5001.
# Losses: G, D Gen, D Real, Xgb: -0.2366, 0.2142, 0.1911, 0.7967
# D Real - D Gen: -0.0231
# Step: 1200 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.0303, 0.0351, 0.1055, 0.9715
# D Real - D Gen: 0.0704
# Step: 1300 of 5001.
# Losses: G, D Gen, D Real, Xgb: -0.0224, 0.0801, 0.0361, 0.9654
# D Real - D Gen: -0.0440
# Step: 1400 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.0766, -0.0715, -0.1505, 0.9065
# D Real - D Gen: -0.0790
# Step: 1500 of 5001.
# Losses: G, D Gen, D Real, Xgb: -0.2313, 0.2583, 0.0505, 1.0000
# D Real - D Gen: -0.2078
# Step: 1600 of 5001.
# Losses: G, D Gen, D Real, Xgb: -0.2166, 0.3442, 0.1528, 0.9756
# D Real - D Gen: -0.1914
# Step: 1700 of 5001.
# Losses: G, D Gen, D Real, Xgb: -0.0238, 0.0110, 0.0783, 0.8984
# D Real - D Gen: 0.0674
# Step: 1800 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.1885, -0.1736, -0.2115, 0.9593
# D Real - D Gen: -0.0379
# Step: 1900 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.8127, -0.8117, -0.8868, 0.9776
# D Real - D Gen: -0.0751
# Step: 2000 of 5001.
# Losses: G, D Gen, D Real, Xgb: 1.1481, -1.1034, -1.1815, 0.9268
# D Real - D Gen: -0.0782
# Step: 2100 of 5001.
# Losses: G, D Gen, D Real, Xgb: 1.6187, -1.5924, -1.6400, 0.9045
# D Real - D Gen: -0.0475
# Step: 2200 of 5001.
# Losses: G, D Gen, D Real, Xgb: 1.4680, -1.4773, -1.5297, 0.7846
# D Real - D Gen: -0.0524
# Step: 2300 of 5001.
# Losses: G, D Gen, D Real, Xgb: 1.2892, -1.3023, -1.3655, 0.9289
# D Real - D Gen: -0.0633
# Step: 2400 of 5001.
# Losses: G, D Gen, D Real, Xgb: 1.0981, -1.0295, -1.0365, 0.8394
# D Real - D Gen: -0.0071
# Step: 2500 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.7528, -0.7362, -0.6175, 0.9146
# D Real - D Gen: 0.1186
# Step: 2600 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.2873, -0.2852, -0.3480, 0.9187
# D Real - D Gen: -0.0628
# Step: 2700 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.2413, -0.2184, -0.2063, 0.8171
# D Real - D Gen: 0.0120
# Step: 2800 of 5001.
# Losses: G, D Gen, D Real, Xgb: -0.1293, 0.1451, 0.0295, 0.9533
# D Real - D Gen: -0.1156
# Step: 2900 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.2259, -0.2118, -0.2261, 0.9207
# D Real - D Gen: -0.0143
# Step: 3000 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.2205, -0.2248, -0.1963, 0.8476
# D Real - D Gen: 0.0285
# Step: 3100 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.1352, -0.1239, -0.1917, 0.9614
# D Real - D Gen: -0.0678
# Step: 3200 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.1370, -0.1075, -0.1611, 0.8841
# D Real - D Gen: -0.0536
# Step: 3300 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.2337, -0.2240, -0.2238, 0.9207
# D Real - D Gen: 0.0002
# Step: 3400 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.2066, -0.1779, -0.2358, 0.8780
# D Real - D Gen: -0.0578
# Step: 3500 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.1563, -0.2047, -0.2734, 0.8780
# D Real - D Gen: -0.0687
# Step: 3600 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.1848, -0.1801, -0.1616, 0.9126
# D Real - D Gen: 0.0185
# Step: 3700 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.1635, -0.1723, -0.1151, 0.8720
# D Real - D Gen: 0.0572
# Step: 3800 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.2538, -0.2582, -0.1971, 0.9817
# D Real - D Gen: 0.0610
# Step: 3900 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.2976, -0.2778, -0.3096, 0.9654
# D Real - D Gen: -0.0318
# Step: 4000 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.1596, -0.1819, -0.1555, 0.9370
# D Real - D Gen: 0.0264
# Step: 4100 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.1265, -0.1246, -0.1549, 0.9431
# D Real - D Gen: -0.0304
# Step: 4200 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.0530, -0.0268, -0.0414, 0.9228
# D Real - D Gen: -0.0146
# Step: 4300 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.1663, -0.1634, -0.1698, 0.9350
# D Real - D Gen: -0.0065
# Step: 4400 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.0295, -0.0538, -0.1081, 0.9533
# D Real - D Gen: -0.0543
# Step: 4500 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.3256, -0.3193, -0.3129, 0.9654
# D Real - D Gen: 0.0064
# Step: 4600 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.1517, -0.1444, -0.0621, 0.9939
# D Real - D Gen: 0.0823
# Step: 4700 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.0953, -0.0846, -0.0801, 0.9309
# D Real - D Gen: 0.0045
# Step: 4800 of 5001.
# Losses: G, D Gen, D Real, Xgb: -0.0102, 0.0661, 0.0367, 0.9512
# D Real - D Gen: -0.0294
# Step: 4900 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.0641, -0.0312, -0.1071, 0.9126
# D Real - D Gen: -0.0760
# Step: 5000 of 5001.
# Losses: G, D Gen, D Real, Xgb: 0.0763, -0.0723, -0.0148, 0.9593
# D Real - D Gen: 0.0576

# %%
data_dim = 3

generator_model, discriminator_model, combined_model = define_models_GAN(rand_dim, data_dim, base_n_count, type='Wasserstein')
generator_model.load_weights('cache/GAN_generator_model_weights_step_5000.h5')

# %%
test_size = 492 # Equal to all of the fraud cases

# x = get_data_batch(train, test_size, seed=i+j)
z = np.random.normal(size=(test_size, rand_dim))

# %%
gz = generator_model.predict(z)

# %%
gz
# Out:
# array([[-0.24557617, -0.7439105 ,  0.95926756],
#        [-0.7123535 ,  1.0223356 ,  0.38850117],
#        [ 0.61866987,  0.20343773, -0.95839727],
#        ...,
#        [-0.1295739 ,  1.6523135 ,  0.7339146 ],
#        [-0.1881922 , -0.9583156 ,  3.6889877 ],
#        [ 0.2620699 , -0.5581088 ,  0.7297507 ]], dtype=float32)

# %%
df_generated = pd.DataFrame(gz)

# %%
df_generated
# Out:
#             0         1         2
# 0   -0.245576 -0.743910  0.959268
# 1   -0.712354  1.022336  0.388501
# 2    0.618670  0.203438 -0.958397
# 3    1.505453 -0.458843 -0.337418
# 4    0.216332 -0.393149  2.008255
# 5   -0.707673  0.051459  0.088722
# 6   -0.100229  0.053725  1.661220
# 7   -0.019040 -1.100737  3.393007
# 8   -1.336935  0.532481  2.251962
# 9    0.661037  0.705527 -0.445044
# 10   1.209866  0.819016  0.934212
# 11  -0.270254  0.689115 -1.071664
# 12   0.698116  1.098943 -0.563626
# 13  -0.005041  1.641212  1.687498
# 14   1.706543  0.835889 -1.201868
# 15  -0.104195 -0.801708  3.115059
# 16   0.571190 -0.147900  0.957436
# 17   1.389732 -0.751935  0.203242
# 18   0.152377 -0.553784  1.553283
# 19   0.930070  0.949135 -0.154730
# 20  -1.050212  1.194512  1.769234
# 21   0.836278  0.593268  0.890198
# 22  -0.286625 -0.278612  2.940858
# 23  -0.473100 -0.649082 -0.018817
# 24   0.358204 -0.397512  1.519610
# 25   0.531817  0.090272  1.483640
# 26  -0.133618  1.748753  0.232864
# 27  -0.801294  1.942712  0.387434
# 28   0.090743 -0.010952  1.755207
# 29   0.377429  0.112931  0.770670
# ..        ...       ...       ...
# 462  0.013740  1.227825  3.717947
# 463 -0.242567 -0.611683  1.512160
# 464  0.232784 -0.319120  1.615542
# 465 -0.413218 -1.055189 -0.645767
# 466 -0.088260  0.571601  0.061807
# 467 -0.470666 -0.873994  1.337885
# 468 -0.144680 -0.141928 -0.637155
# 469  0.661144  0.193348  1.797551
# 470  0.459336  0.173225  1.382386
# 471  0.683053  0.466181 -0.186776
# 472  0.091338 -0.827635  1.833730
# 473 -0.308929  1.113118  0.423561
# 474 -0.086257 -0.262833 -0.700601
# 475 -0.542639 -0.713722  0.852631
# 476 -0.156479 -0.775633  3.247965
# 477 -0.474589  0.315465  1.396300
# 478  0.792353  0.024200  2.181274
# 479 -0.759739  0.251861  1.730155
# 480  0.487617  1.574044 -0.809213
# 481  0.888197  0.545946  0.171445
# 482  0.094309 -0.517634  1.758690
# 483 -0.398324  0.819092  0.527204
# 484 -1.121205  0.033577  2.026613
# 485 -0.795920 -0.085161  2.271710
# 486  1.091197  1.030111  0.220610
# 487 -0.057554 -0.538731  1.306026
# 488 -0.514201  0.422605 -0.337000
# 489 -0.129574  1.652313  0.733915
# 490 -0.188192 -0.958316  3.688988
# 491  0.262070 -0.558109  0.729751
#
# [492 rows x 3 columns]

# %%
plt.hist(df['a'])
# Out:
# (array([  3.,   7.,  36., 110., 200., 244., 217., 132.,  41.,  10.]),
#  array([-3.56248147, -2.9299246 , -2.29736774, -1.66481087, -1.03225401,
#         -0.39969714,  0.23285973,  0.86541659,  1.49797346,  2.13053032,
#          2.76308719]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df_generated[0])
# Out:
# (array([16., 28., 51., 88., 91., 65., 67., 56., 25.,  5.]),
#  array([-1.4654958 , -1.1039367 , -0.7423775 , -0.38081837, -0.01925921,
#          0.34229994,  0.7038591 ,  1.0654182 ,  1.4269774 ,  1.7885365 ,
#          2.1500957 ], dtype=float32),
#  <a list of 10 Patch objects>)
